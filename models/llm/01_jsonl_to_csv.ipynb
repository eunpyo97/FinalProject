# %% [markdown]
# # jsonl을 csv로 변환

# %%
import json
import pandas as pd
import os

data_folder = "../../data/"  
jsonl_files = ["total_kor_counsel_bot.jsonl", "total_kor_multiturn_counsel_bot.jsonl"]  
csv_files = ["total_kor_counsel_bot.csv", "total_kor_multiturn_counsel_bot.csv"]  

# JSONL → CSV 변환
for i in range(len(jsonl_files)):  # zip() 대신 index 기반 접근
    jsonl_path = os.path.join(data_folder, jsonl_files[i])
    csv_path = os.path.join(data_folder, csv_files[i])

    data = []
    with open(jsonl_path, "r", encoding="utf-8") as f:
        for line in f:
            data.append(json.loads(line))

    df = pd.DataFrame(data)

    df.to_csv(csv_path, index=False, encoding="utf-8")

    print(f"✅ {jsonl_files[i]} → {csv_files[i]} 변환 완료! (저장 경로: {csv_path})")
# Out:
# ✅ total_kor_counsel_bot.jsonl → total_kor_counsel_bot.csv 변환 완료! (저장 경로: ../data/total_kor_counsel_bot.csv)
# ✅ total_kor_multiturn_counsel_bot.jsonl → total_kor_multiturn_counsel_bot.csv 변환 완료! (저장 경로: ../data/total_kor_multiturn_counsel_bot.csv)

# %% [markdown]
# # total_kor_counsel_bot.csv 분석

# %% [markdown]
# - \n을 공백으로 변경
# - 2개 이상의 연속 공백 단일 공백으로 변환하고 앞뒤 공백 제거
# - 특수문자는 있긴하지만 제외는 하지 않음 -> 대화중에 쓰는 경우 고려
# - 완전히 중복된 데이터 제거

# %%
import pandas as pd

csv_file = "../../data/total_kor_counsel_bot.csv"

# %%
df = pd.read_csv(csv_file)

num_rows = len(df)
num_columns = len(df.columns)

print(f"총 데이터 개수: {num_rows}개")
print(f"총 컬럼 개수: {num_columns}개")
print("\n 데이터 컬럼명:")
print(df.columns)
print(df.head())
# Out:
# 총 데이터 개수: 13234개
# 총 컬럼 개수: 2개
#
#  데이터 컬럼명:
# Index(['input', 'output'], dtype='object')
#                                                input  \
# 0  저 사실, 약간 중2병 같은 걸 증상을 보이고 있습니다.\n그래서 대학교를 가면서도...
# 1  회사에서 일이 너무 바빠서 스트레스 받아요.\n회사에서 일이 너무 많아서 스트레스 ...
# 2  남들에게 이상해보인다는 생각 때문에 항상 불안하고 스트레스 받아요. 눈치보지 말라고...
# 3  요즘 회사에서 일이 많아지면서 나 혼자 다 이뤄내야 한다는 압박감이 들어요. 이전에...
# 4  저는 요즘 일이 많아지면서 체력적으로도, 정신적으로도 지치게 됐어요. 마감기한이 얼...
#
#                                               output
# 0  사우님이 중2병적인 행동과 태도를 가지고 있다고 느껴져 스트레스를 받으시는 상황입니...
# 1  사우님이 회사에서 일이 너무 많아서 지쳐서 스트레스를 받고 있으시다는데요. 하루종일...
# 2  사우님 남들에게 이상하게 보일까봐 불안하고 스트레스 받으시네요. 눈치보지 말라고 해...
# 3  사우님은 회사에서 일이 많아져서 혼자 다 처리해야 하는 압박감 때문에 불안감을 느끼...
# 4  사우님 요즘 일이 많아지면서 체력적으로도, 정신적으로도 지친 상태이고 일 할 때마다...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13234 entries, 0 to 13233
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   13234 non-null  object
#  1   output  13234 non-null  object
# dtypes: object(2)
# memory usage: 206.9+ KB

# %%
# input 컬럼에서 \n 포함된 개수
num_input_newline = df["input"].astype(str).str.contains("\n").sum()

# output 컬럼에서 \n 포함된 개수
num_output_newline = df["output"].astype(str).str.contains("\n").sum()

print(f"input 컬럼에서 \\n 포함된 개수: {num_input_newline}개")
print(f"output 컬럼에서 \\n 포함된 개수: {num_output_newline}개")
# Out:
# input 컬럼에서 \n 포함된 개수: 6314개
# output 컬럼에서 \n 포함된 개수: 13234개

# %%
# \n을 공백으로 변경 -> 한 줄로 만들기
df["input"] = df["input"].str.replace("\n", " ", regex=True)
df["output"] = df["output"].str.replace("\n", " ", regex=True)

print(f"\\n 제거 완료!")
# Out:
# \n 제거 완료!

# %%
# input 컬럼에서 \n 포함된 개수
num_input_newline = df["input"].astype(str).str.contains("\n").sum()

# output 컬럼에서 \n 포함된 개수
num_output_newline = df["output"].astype(str).str.contains("\n").sum()

print(f"input 컬럼에서 \\n 포함된 개수: {num_input_newline}개")
print(f"output 컬럼에서 \\n 포함된 개수: {num_output_newline}개")
# Out:
# input 컬럼에서 \n 포함된 개수: 0개
# output 컬럼에서 \n 포함된 개수: 0개

# %%
#  2개 이상의 연속 공백 개수 확인 (\s+ 패턴 존재 여부)
num_input_spaces = df["input"].astype(str).str.contains(r"\s{2,}").sum()
num_output_spaces = df["output"].astype(str).str.contains(r"\s{2,}").sum()

print(f"input 컬럼에서 연속된 공백 포함된 개수: {num_input_spaces}개")
print(f"output 컬럼에서 연속된 공백 포함된 개수: {num_output_spaces}개")
# Out:
# input 컬럼에서 연속된 공백 포함된 개수: 1017개
# output 컬럼에서 연속된 공백 포함된 개수: 10785개

# %%
# 연속된 공백을 단일 공백으로 변환하고 앞뒤 공백 제거
df["input"] = df["input"].str.replace(r"\s+", " ", regex=True).str.strip()
df["output"] = df["output"].str.replace(r"\s+", " ", regex=True).str.strip()

num_input_spaces = df["input"].astype(str).str.contains(r"\s{2,}").sum()
num_output_spaces = df["output"].astype(str).str.contains(r"\s{2,}").sum()

print(f"input 컬럼에서 연속된 공백 포함된 개수: {num_input_spaces}개")
print(f"output 컬럼에서 연속된 공백 포함된 개수: {num_output_spaces}개")
# Out:
# input 컬럼에서 연속된 공백 포함된 개수: 0개
# output 컬럼에서 연속된 공백 포함된 개수: 0개

# %%
import re

# HTML 태그 포함 여부 확인
num_input_html = df["input"].astype(str).str.contains(r"<[^>]+>").sum()
num_output_html = df["output"].astype(str).str.contains(r"<[^>]+>").sum()

print(f"input 컬럼에서 HTML 태그 포함 개수: {num_input_html}개")
print(f"output 컬럼에서 HTML 태그 포함 개수: {num_output_html}개")

# 이상한 특수문자 포함 여부 확인
num_input_special = df["input"].astype(str).str.contains(r"[^가-힣a-zA-Z0-9\s.,!?]").sum()
num_output_special = df["output"].astype(str).str.contains(r"[^가-힣a-zA-Z0-9\s.,!?]").sum()

print(f"input 컬럼에서 이상한 특수문자 포함 개수: {num_input_special}개")
print(f"output 컬럼에서 이상한 특수문자 포함 개수: {num_output_special}개")
# Out:
# input 컬럼에서 HTML 태그 포함 개수: 0개
# output 컬럼에서 HTML 태그 포함 개수: 0개
# input 컬럼에서 이상한 특수문자 포함 개수: 642개
# output 컬럼에서 이상한 특수문자 포함 개수: 10058개

# %%
num_duplicates = df.duplicated(subset=["input", "output"]).sum()
print(f"중복된 질문-답변 개수: {num_duplicates}개")
# Out:
# 중복된 질문-답변 개수: 30개

# %%
# 중복된 질문-답변 데이터 추출
duplicate_rows = df[df.duplicated(subset=["input", "output"], keep=False)]

print(duplicate_rows.head(30))
# Out:
#                                                    input  \
# 172    실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 216    실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 784    실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 1505   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 1639   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 1876   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 2471   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 2483   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 3185   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 3457   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 3642   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 4596   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 5795   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 6395   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 6527   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 6780   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 7262   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 7326   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 7563   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 7947   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 8215   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 8333   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 8843   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 9244   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 9285   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 9472   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 9891   실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 10796  실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 11010  실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# 11855  실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
#
#                                                   output
# 172    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 216    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 784    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 1505   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 1639   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 1876   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 2471   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 2483   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 3185   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 3457   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 3642   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 4596   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 5795   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 6395   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 6527   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 6780   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 7262   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 7326   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 7563   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 7947   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 8215   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 8333   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 8843   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 9244   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 9285   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 9472   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 9891   사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 10796  사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 11010  사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# 11855  사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...

# %%
# CSV로 저장
duplicate_rows.to_csv("../../data/duplicates_review.csv", index=False, encoding="utf-8")

print("중복된 질문-답변 30개를 duplicates_review.csv 파일로 저장했습니다.")
# Out:
# 중복된 질문-답변 30개를 duplicates_review.csv 파일로 저장했습니다.

# %%
# 중복된 질문-답변 데이터 찾기 (keep=False: 모든 중복된 행을 표시)
duplicate_indices = df[df.duplicated(subset=["input", "output"], keep=False)].index

# 앞뒤 행 포함해서 출력
for idx in duplicate_indices:
    print("\n중복 데이터 전후 문맥 확인")
    
    if idx > 0:
        print(f"\n이전 데이터 (index {idx-1}):\n{df.iloc[idx-1]}\n")
    print(f"\n중복된 데이터 (index {idx}):\n{df.iloc[idx]}\n")

    if idx < len(df) - 1:
        print(f"\n다음 데이터 (index {idx+1}):\n{df.iloc[idx+1]}\n")
    print("-" * 80)
# Out:
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 171):
# input     저는 회사에서 매니저님과 서로 다른 의견을 제시하게 되면 자신의 생각을 피력하는 것...
# output    사우님 매니저님과 다른 의견을 제시하면 자신의 생각을 말하기 어렵다고 하시네요. 매...
# Name: 171, dtype: object
#
#
# 중복된 데이터 (index 172):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 172, dtype: object
#
#
# 다음 데이터 (index 173):
# input     요즘 집에서 일하니까 매일 같이 먹고 자는 가족들 때문에 집안 일에 불만이 많이 생...
# output    사우님이 요즘 집에서 일하면서 가족들과 함께 지내다보니 가족들이 자신들이 하는 일에...
# Name: 173, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 215):
# input     요즘 내가 이상한 것 같아요. 학교에 가는 것도 싫고, 친구들과 놀기도 귀찮고, 집...
# output    사우님 요즘은 학교에 가는 것도 싫고, 친구들과 놀기도 귀찮고, 집에서 아무것도 하...
# Name: 215, dtype: object
#
#
# 중복된 데이터 (index 216):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 216, dtype: object
#
#
# 다음 데이터 (index 217):
# input     업무가 지금 너무 바쁘게 진행되고 있어서, 언제 일을 끝낼지 모르겠습니다. 대부분의...
# output    사우님 업무량과 업무의 성격 상 인간과 관련된 일이 많아 무언가 문제가 생길 가능성...
# Name: 217, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 783):
# input     최근 회사에서 압박감이 너무 커요. 일정이 많이 쌓여서 일하는데도 손이 따라가지 않...
# output    사우님 최근 회사에서 압박감을 느끼시고 있으며 일정이 많아지고, 계속 늦은 시간까지...
# Name: 783, dtype: object
#
#
# 중복된 데이터 (index 784):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 784, dtype: object
#
#
# 다음 데이터 (index 785):
# input     요즘 학교에 가기 싫어져서 가지 않고 있습니다. 학교에 가면 지겨운 시간이 길어져서...
# output    사우님 학교에 가기 싫어지셨다고 하셨네요. 학교에서 지겨운 시간을 보내시다 보니 학...
# Name: 785, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 1504):
# input     저는 신입사원인데, 나름대로 일을 열심히 하고 있습니다. 하지만 동료들은 다들 저보...
# output    신입사원인 사우님은 동료들과 같은 업무량에 비해 일 처리에 어려움을 느끼시는 상황입...
# Name: 1504, dtype: object
#
#
# 중복된 데이터 (index 1505):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 1505, dtype: object
#
#
# 다음 데이터 (index 1506):
# input     저번주부터 잠을 못 이루겠어요. 학교다녀오면 집에서 공부하고 공부만하다가 자기전에는...
# output    사우님, 요즘 잠을 잘 못 이루고 있으시다고 하셨는데요, 학교 다녀오시면 집에서 공...
# Name: 1506, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 1638):
# input     요즘에 집에서만 있으면 자꾸 우울해지고 슬퍼지고, 그래서 영화를 보거나 게임을 하며...
# output    사우님 요즘 집에서만 있으면 우울하고 슬프고 행복하지 않으며, 영화나 게임을 하며 ...
# Name: 1638, dtype: object
#
#
# 중복된 데이터 (index 1639):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 1639, dtype: object
#
#
# 다음 데이터 (index 1640):
# input     저는 어렸을때 어머니와의 대화가 잘 되지 않아서 어머니와의 대화가 불편합니다. 어머...
# output    사우님은 어렸을 때부터 어머니와 대화가 잘 되지 않아 불편한 감정을 느끼고 있으신 ...
# Name: 1640, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 1875):
# input     요즘 이상하게 매우 무기력하고, 힘이 없어요. 배고픈데도 먹고 싶은 음식이 없어요....
# output    사우님 요즘 매우 무기력하고 기운이 없으며 머리가 아프고 이상한 소리가 들려 잠도 ...
# Name: 1875, dtype: object
#
#
# 중복된 데이터 (index 1876):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 1876, dtype: object
#
#
# 다음 데이터 (index 1877):
# input     최근 직장생활에서 계속 불만족스러운 점들이 생겨서 고민입니다. 입사하고 처음에는 기...
# output    사우님 입사하신지 얼마 안 된 시점에서 일을 하면서 초기에는 좋았던 기쁨이 최근들어...
# Name: 1877, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 2470):
# input     일이 너무 많아져서 제대로 된 급여를 받지 못하면서도 일을 벌리면서 스트레스가 많이...
# output    사우님은 일이 너무 많아져서 제대로 된 급여를 받지 못하면서도 일을 벌리면서 스트레...
# Name: 2470, dtype: object
#
#
# 중복된 데이터 (index 2471):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 2471, dtype: object
#
#
# 다음 데이터 (index 2472):
# input     무슨 일을 하나 잘해도 칭찬을 못받으면 기분이 좋지 않아요. 그러다 보면, 똑같은 ...
# output    사우님이 잘하는 일이 있음에도 불구하고 칭찬을 못받으면 기분이 좋지 않아 똑같은 실...
# Name: 2472, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 2482):
# input     직장생활을 시작한지 얼마 안되었는데 어떤 것도 잘 모르겠어요. 업무를 시작할 때마다...
# output    사우님은 직장생활을 시작한지 얼마 되지 않았는데, 업무를 시작할 때마다 헷갈리고 당...
# Name: 2482, dtype: object
#
#
# 중복된 데이터 (index 2483):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 2483, dtype: object
#
#
# 다음 데이터 (index 2484):
# input     집에서 나가기 싫어요. 요즘 집에만 있고 밖에 나가기 싫어요. 친구도 없고 볼 일도...
# output    사우님은 요즘 집에만 있고 밖에 나가기 싫은 마음이 많아 고통스럽다고 하시네요. 친...
# Name: 2484, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 3184):
# input     예전에 제가 참여했던 프로젝트에서의 경험이 이번 프로젝트에서도 다시 일어나지 않을까...
# output    예전에 참여했던 프로젝트에서는 지원분야와 크게 상관없는 분야의 프로젝트였는데 대부분...
# Name: 3184, dtype: object
#
#
# 중복된 데이터 (index 3185):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 3185, dtype: object
#
#
# 다음 데이터 (index 3186):
# input     상사가 너무 불친절해요. 저는 지난 회사에서 근무하다가 지금은 새로운 회사에 들어와...
# output    사우님 지금 일하는 회사에서 상사가 너무 불친절하다고 느끼고 있으며, 업무지시를 제...
# Name: 3186, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 3456):
# input     업무가 너무 많습니다. 제가 맡은 업무는 다른 분들이 하시던 일을 저에게 맡기신 건...
# output    사우님이 맡은 업무가 다른 분들이 하시던 일을 사우님께 맡기신 건데, 업무량이 많아...
# Name: 3456, dtype: object
#
#
# 중복된 데이터 (index 3457):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 3457, dtype: object
#
#
# 다음 데이터 (index 3458):
# input     저희 회사에서 업무를 마치고 집에 가면 저의 딸이 이미 자고 있어요. 그렇기 때문에...
# output    사우님은 업무를 마치고 집에 도착할 때 딸이 이미 자고 있어 딸과 함께할 시간도 거...
# Name: 3458, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 3641):
# input     요즘들어 매일매일 힘들어요. 매일매일 같이 지내는 직장 동료들과의 대화에서도 기운이...
# output    사우님 요즘들어 매일매일 힘들어지고 있다고 하셨네요. 직장 동료들과 대화를 나누는 ...
# Name: 3641, dtype: object
#
#
# 중복된 데이터 (index 3642):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 3642, dtype: object
#
#
# 다음 데이터 (index 3643):
# input     갈수록 학교에서 친구들과 소외감을 느끼고 있어요. 나는 학교에서 교복 입고 다녀야 ...
# output    사우님은 학교에서 교복을 입고 꼭대기 자리에서 공부해야 하고, 그렇게 하지 않으면 ...
# Name: 3643, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 4595):
# input     가족들과 제가 가진 문제 때문에 자주 다투게 됩니다. 사소한 일이 있어도 서로 몹시...
# output    가족과 사소한 일 때문에 서로 화를 내고, 서로 지적하며 답답해하게 된다는 고민을 ...
# Name: 4595, dtype: object
#
#
# 중복된 데이터 (index 4596):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 4596, dtype: object
#
#
# 다음 데이터 (index 4597):
# input     제가 취직한 회사에서 가끔식 상사들끼리 저를 괴롭히는 언어와 행동이 있어요. 그리고...
# output    사우님 취직한 회사에서 가끔식 상사들끼리 괴롭히는 언어와 행동이 있으며 연락이 와도...
# Name: 4597, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 5794):
# input     요즘 동생과 학교에서 싸우곤 합니다. 제가 하는 말에 항상 반발하며 제가 보는 것과...
# output    사우님 요즘 동생과 학교에서 자꾸 싸우시는데요. 서로 볼것도 다르고 제가 보는 것과...
# Name: 5794, dtype: object
#
#
# 중복된 데이터 (index 5795):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 5795, dtype: object
#
#
# 다음 데이터 (index 5796):
# input     최근 같이 일하고 있는 직원이 제가 다른 상사들보다 적은 일을 하고 있는것 같아요....
# output    사우님과 같이 일하고 있는 직원이 일을 많이 안하는 것 같아서 불만이 생기셨네요. ...
# Name: 5796, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 6394):
# input     요즘 회사 일 때문에 많이 스트레스 받는 것 같아요. 남들은 다 잘하는데 나만 못하...
# output    사우님은 회사 업무를 하면서 남들보다 못해서 업무에 대해 걱정하고 자신감이 떨어져 ...
# Name: 6394, dtype: object
#
#
# 중복된 데이터 (index 6395):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 6395, dtype: object
#
#
# 다음 데이터 (index 6396):
# input     친한 친구 둘이 서로 이성친구랑 연락하고 있는 걸 보고 놀랐어요. 저와 저 친구는 ...
# output    사우님 중학교 때부터 친한 친구가 제가 좋아하는 사람과 이성친구로 연락하는 모습을 ...
# Name: 6396, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 6526):
# input     요즘 저는 직장에서 불이익을 받은 것 같습니다. 저는 부서장이 되기 위해 노력해왔는...
# output    사우님은 제안한 기획안이 좋은 아이디어라고 생각했지만 다른 부장들이 기획안에 비판적...
# Name: 6526, dtype: object
#
#
# 중복된 데이터 (index 6527):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 6527, dtype: object
#
#
# 다음 데이터 (index 6528):
# input     요즘 회사에서 제가 한 일이 누락된 경우가 있어서 직원들에게 신뢰를 잃는 것 같아요...
# output    사우님 요즘 회사에서 제가 한 일이 누락된 경우가 있어서 직원들에게 신뢰를 잃는 것...
# Name: 6528, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 6779):
# input     어릴때 가족때문에 너무 많은 고통을 겪었어요. 제가 어렸을 때 아버지께서 운전하시다...
# output    어렸을 때 가족관계에서 교통사고와 이혼, 가족간의 갈등 등 많은 고통을 겪으셨습니다...
# Name: 6779, dtype: object
#
#
# 중복된 데이터 (index 6780):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 6780, dtype: object
#
#
# 다음 데이터 (index 6781):
# input     제 동생이 알바를 하다가 연락이 안되요. 아직 연락이 안와서 너무 걱정돼서 말이에요...
# output    사우님 동생이 알바를 하다가 연락이 안와 걱정된다고 하셨네요. 제 동생은 어디서 뭘...
# Name: 6781, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 7261):
# input     평소엔 그렇게 힘들진 않았는데, 요즘은 집에 가기 싫어지네요. 출근하면 누구나 지쳐...
# output    사우님 요즘 직장에서 지쳐있는 느낌이 드신다고 하셨네요. 근무시간이 지날수록 지치고...
# Name: 7261, dtype: object
#
#
# 중복된 데이터 (index 7262):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 7262, dtype: object
#
#
# 다음 데이터 (index 7263):
# input     최근에 친한 친구가 다른 친구와 데이트를 한다는 소식을 들었어요. 그런데 저는 그 ...
# output    사우님 친구가 다른 친구와 데이트를 한다는 소식을 듣고 계획했던 일이 취소되어 마음...
# Name: 7263, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 7325):
# input     요즘 저는 많이 우울하고 나를 너무 싫어해요. 대학교를 입학하고 나서 처음으로 제 ...
# output    사우님은 대학교 입학 후 처음으로 자신을 싫어하는 감정을 느끼시고, 타인의 시선을 ...
# Name: 7325, dtype: object
#
#
# 중복된 데이터 (index 7326):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 7326, dtype: object
#
#
# 다음 데이터 (index 7327):
# input     제 부모님은 모든 걸 다 알아서 해결해 주시려고 하시는데, 이게 도움이 될까요? 평...
# output    사우님, 제가 드릴 수 있는 상담의 내용을 듣고나니 어떻게 시작할지 모르는 상황에서...
# Name: 7327, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 7562):
# input     요즘 일에 대한 만족도가 너무 낮아요. 원래 그렇지는 않았는데, 요즘 들어서 일을 ...
# output    사우님 일을 하면 할수록 기분이 나빠지고 있고 근무 시간이 지나면 도망치고 싶은 기...
# Name: 7562, dtype: object
#
#
# 중복된 데이터 (index 7563):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 7563, dtype: object
#
#
# 다음 데이터 (index 7564):
# input     고민이 있는데요…. 저는 직장에서 업무를 하는데, 한 명의 동료 직원이 저에게 항상...
# output    사우님은 직장에서 업무를 하면서 한 명의 동료 직원의 태도로 인해 불편함을 느끼고 ...
# Name: 7564, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 7946):
# input     요즘 왜 불안하고 우울한지 모르겠어요. 요즘들어 불안과 우울함이 극에 달해져서 힘들...
# output    요즘들어 갑자기 불안감과 우울함이 와서 힘들어하시는 것 같아요. 어디서부터 문제가 ...
# Name: 7946, dtype: object
#
#
# 중복된 데이터 (index 7947):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 7947, dtype: object
#
#
# 다음 데이터 (index 7948):
# input     지금 일하는 회사에 문제가 많아서 스트레스 받아요. 회사 분위기가 힘들고 제가 받은...
# output    사우님의 회사 분위기가 나쁘고 업무량이 많아지면서 스트레스를 많이 받고 있는 것 같...
# Name: 7948, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 8214):
# input     제 직장은 외국계 무역회사인데, 아직 영어 실력이 부족한 상태에서 일하는게 너무 힘...
# output    사우님이 일하시는 외국계 무역회사에서는 이메일 대화가 많은 업무환경에서 업무에 지장...
# Name: 8214, dtype: object
#
#
# 중복된 데이터 (index 8215):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 8215, dtype: object
#
#
# 다음 데이터 (index 8216):
# input     저, 고등학교 선생님이에요. 그런데 교실에서 학생들과 대화를 하려고 하면 제 마음이...
# output    사우님 고등학교 교사이신데 교실에서 학생들과 대화하려고 하면 마음이 무겁고 긴장되고...
# Name: 8216, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 8332):
# input     저는 직장에서 일하는데요. 최근에 직장에서 힘들어져서 자꾸 일하러 가기 싫어져요. ...
# output    사우님은 최근 직장에서 힘들어져서 일하러 가기 싫은 마음이 드신다고 합니다. 근무지...
# Name: 8332, dtype: object
#
#
# 중복된 데이터 (index 8333):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 8333, dtype: object
#
#
# 다음 데이터 (index 8334):
# input     요즘 학교에서 새로운 학생이 왔는데요, 제가 많이 지나치게 따지고 까다롭게 대하면서...
# output    사우님의 학교에서는 새로운 친구가 오셨는데요, 사우님이 그 친구를 지나치게 따지고 ...
# Name: 8334, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 8842):
# input     회사일이 점점 부담이 됩니다. 회사일이 점점 부담이 됩니다. 회사가 흥하면 좋겠지만...
# output    사우님 회사에서 일하시면서 이제는 일도 힘들게 느껴지며 스트레스도 많이 쌓이고 있으...
# Name: 8842, dtype: object
#
#
# 중복된 데이터 (index 8843):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 8843, dtype: object
#
#
# 다음 데이터 (index 8844):
# input     지난주에 부모님과 큰 싸움을 하고 이후로 내가 머리 아픈 일들이 더 많아졌어요. 부...
# output    사우님 부모님과 큰 싸움을 한 이후로 심리적으로 안정을 잃으셨네요. 부모님과의 대화...
# Name: 8844, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 9243):
# input     저는 학교에서 스타트업을 선발하는 대회에 출전할 예정입니다. 하지만 대회를 앞두고,...
# output    학교에서 대회에 출전할 예정인 사우님이 계신데 프로젝트 구성원들과 갈등이 생겨 문제...
# Name: 9243, dtype: object
#
#
# 중복된 데이터 (index 9244):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 9244, dtype: object
#
#
# 다음 데이터 (index 9245):
# input     요즘 회사 일이 너무 많아서 바빠요. 그런데도 일이 줄지가 않고, 오히려 늘어나고 ...
# output    사우님이 어려운 일을 먼저 끝내고 싶어 하면서도 회사일이 많아지면서 일을 마무리하지...
# Name: 9245, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 9284):
# input     직장에서 제가 하는 업무가 늘어나고, 이전에는 잘했던 일도 잘 못해서 새로운 도전에...
# output    사우님은 직장에서 새로운 업무와 책임이 늘어남에 따라 스트레스를 느끼고 자기 존중감...
# Name: 9284, dtype: object
#
#
# 중복된 데이터 (index 9285):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 9285, dtype: object
#
#
# 다음 데이터 (index 9286):
# input     회사에서 일을 너무 많이 맡아서 힘들어요. 요즘은 일만 하는 것 같아요. 이젠 퇴근...
# output    사우님이 일을 너무 많이 맡아서 바쁘고 힘드시고요, 이전에는 회사 일만 잠시 끝내고...
# Name: 9286, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 9471):
# input     누군가에게 보호받고 싶어요. 요즘 외로움을 많이 느껴요. 불안하고, 대인관계가 부족...
# output    사우님은 요즘 대인관계가 부족하고 외로움을 느끼는데, 이때 혼자만의 시간을 가지는 ...
# Name: 9471, dtype: object
#
#
# 중복된 데이터 (index 9472):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 9472, dtype: object
#
#
# 다음 데이터 (index 9473):
# input     제 직업이 마음에 안드는데 바꾸기가 쉽지 않아요. 열심히 일해서 성과는 얻어내지만,...
# output    사우님은 열심히 일해 성과를 내고 있지만, 직원들과의 분위기가 잘 맞지 않아 힘드신...
# Name: 9473, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 9890):
# input     친구와 싸웠는데, 그 친구는 저한테 연락을 하지 않네요. 저는 친구들과 지내는 것을...
# output    사우님 친구와 싸웠을 때 친구가 무례한 태도를 보여줘서 상처받으셨어요. 친구에게 연...
# Name: 9890, dtype: object
#
#
# 중복된 데이터 (index 9891):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 9891, dtype: object
#
#
# 다음 데이터 (index 9892):
# input     제가 부모님이 재산 분쟁으로 결국 가출을 해서 현재 생활비와 대출금까지 다 챙겨서 ...
# output    사우님은 부모님과의 재산분쟁으로 인해 가출을 해서 현재까지는 생활비와 대출금까지 모...
# Name: 9892, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 10795):
# input     친구와 대화를 하면서도 자꾸 마음 한 구석에선 다른 생각을 하게 돼요. 이상한 짓을...
# output    사우님은 친구와 대화를 하면서도 자꾸 마음 한 구석에선 다른 생각을 하게 돼요. 이...
# Name: 10795, dtype: object
#
#
# 중복된 데이터 (index 10796):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 10796, dtype: object
#
#
# 다음 데이터 (index 10797):
# input     요즘 회사에서 일하는 것이 더욱 힘들어지는 것 같아요. 저는 내가 부족한 것이라고 ...
# output    사우님이 일하는 회사에서 성과에 대한 기대감이 높아지며 스트레스가 많이 쌓이고 있으...
# Name: 10797, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 11009):
# input     저희 부모님께서 제가 직장을 구하지 못해 가지 못한 회사를 계속 언급하시면서 제 자...
# output    사우님은 부모님께서 가지 못했던 회사를 계속 언급하시면서 자신감이 낮아지고 부족한 ...
# Name: 11009, dtype: object
#
#
# 중복된 데이터 (index 11010):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 11010, dtype: object
#
#
# 다음 데이터 (index 11011):
# input     지금 막 울고 싶은데 어떡하죠? 제가 우울증 치료를 받고 있어요. 그런데 요즘에는 ...
# output    사우님 요즘 울고 싶고, 머리에 울음이 쌓이는 느낌이 드시다니 정말 힘드셨겠습니다....
# Name: 11011, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 11854):
# input     회사에서 이직을 준비하고 있는데 어떤 걸 준비해야 할까요? 어떻게하면 이직을 성공할...
# output    사우님은 현재 직장에서 이직을 준비하시는 상황이시네요. 이직을 준비하면서 이직에 대...
# Name: 11854, dtype: object
#
#
# 중복된 데이터 (index 11855):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 11855, dtype: object
#
#
# 다음 데이터 (index 11856):
# input     제가 제대로 선택한 일이 아닌거 같아요. 원래는 좋아했는데, 요즘은 일이 너무 힘들...
# output    사우님 원래는 일을 좋아했지만 요즘에는 일이 너무 힘들어서 퇴사하고 싶다는 생각이 ...
# Name: 11856, dtype: object
#
# --------------------------------------------------------------------------------
#
# 중복 데이터 전후 문맥 확인
#
# 이전 데이터 (index 12328):
# input     내가 지금 직장에서 하는 일이 제대로 된 일인지 모르겠어요. 시간도 어디에 쓰고 있...
# output    사우님 제대로 된 일을 하고 있는지 모르겠다는 불안감을 느끼고 일을 하기 싫어진다고...
# Name: 12328, dtype: object
#
#
# 중복된 데이터 (index 12329):
# input     실수를 너무 많이해요. 저는 시험이라는 글자가 나오고나 들어도 속이 울렁거리고 기분...
# output    사우님 시험을 잘보지 못할까 걱정되는 마음에 시험에서 실수하면 안된다고 생각하시네요...
# Name: 12329, dtype: object
#
#
# 다음 데이터 (index 12330):
# input     요즘에는 직장생활 때문에 스트레스를 많이 받고 있는 것 같아요. 자꾸 일이 너무 많...
# output    사우님은 현재 직장생활로 인해 스트레스를 많이 받고 있으며, 어떻게 하면 일을 더 ...
# Name: 12330, dtype: object
#
# --------------------------------------------------------------------------------

# %%
# 중복된 질문-답변 데이터 찾기 (keep=False: 모든 중복된 행 표시)
duplicate_indices = df[df.duplicated(subset=["input", "output"], keep=False)].index

# 앞뒤 행 포함한 데이터 저장을 위한 리스트
review_data = []

for idx in duplicate_indices:
    row = {
        "index": idx,
        "prev_input": df.iloc[idx - 1]["input"] if idx > 0 else "",
        "prev_output": df.iloc[idx - 1]["output"] if idx > 0 else "",
        "duplicate_input": df.iloc[idx]["input"],
        "duplicate_output": df.iloc[idx]["output"],
        "next_input": df.iloc[idx + 1]["input"] if idx < len(df) - 1 else "",
        "next_output": df.iloc[idx + 1]["output"] if idx < len(df) - 1 else "",
    }
    review_data.append(row)

# 데이터프레임 변환
df_review = pd.DataFrame(review_data)

# CSV로 저장
csv_path = "../data/../duplicates_review_with_context.csv"
df_review.to_csv(csv_path, index=False, encoding="utf-8")

print(f"중복 데이터 확인용 CSV 저장 완료! (경로: {csv_path})")
# Out:
# 중복 데이터 확인용 CSV 저장 완료! (경로: ../data/duplicates_review_with_context.csv)

# %%
# 완전히 동일한 중복된 데이터 제거
df = df.drop_duplicates(subset=["input", "output"], keep="first").reset_index(drop=True)

# 중복 개수 다시 확인
num_duplicates_after = df.duplicated(subset=["input", "output"]).sum()

print(f"중복 제거 후 남은 중복된 질문-답변 개수: {num_duplicates_after}개")
# Out:
# 중복 제거 후 남은 중복된 질문-답변 개수: 0개

# %%
# 질문 & 답변 길이 확인 (토큰 기준이 아니라 글자 수 기준)
df["input_length"] = df["input"].str.len()
df["output_length"] = df["output"].str.len()

# 300자 이상인 데이터 개수 확인
long_inputs = (df["input_length"] > 300).sum()
long_outputs = (df["output_length"] > 300).sum()

print(f"300자 이상 긴 질문 개수: {long_inputs}개")
print(f"300자 이상 긴 답변 개수: {long_outputs}개")
# Out:
# 300자 이상 긴 질문 개수: 777개
# 300자 이상 긴 답변 개수: 13204개

# %%
clean_csv_path = "../data/../total_kor_counsel_bot_clean.csv"
df.to_csv(clean_csv_path, index=False, encoding="utf-8")

print(f"데이터 저장 완료! (경로: {clean_csv_path})")
# Out:
# 데이터 저장 완료! (경로: ../data/total_kor_counsel_bot_clean.csv)
